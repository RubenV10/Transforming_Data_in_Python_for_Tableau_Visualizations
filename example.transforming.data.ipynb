# %%
import pandas as pd
import numpy as np
import glob

import os
os.chdir("C:/Users/Ruben/Desktop/Python Repository")

# %% [markdown]
# ##### Load Data

# %%
#load - MSB/Deposit SARs, all states 2020-2021 aggregated at the county / file type level
# the glob package imports multiple csv files (21 files in this instance) at once from a single folder
path = r"C:\Users\Ruben\Desktop\Python Repository\dep.msb.AL-WY.20-21.countysusp"
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, thousands=",")
    li.append(df)

data = pd.concat(li, axis=0, ignore_index=True)

# %%
data
# Out:
#                 Year Month    State              Countym  \
# 0             2020 January  Alabama   Autauga County, AL
# 1             2020 January  Alabama   Autauga County, AL
# 2             2020 January  Alabama   Autauga County, AL
# 3             2020 January  Alabama   Autauga County, AL
# 4             2020 January  Alabama   Autauga County, AL
# ...                    ...      ...                  ...
# 1550581      2021 December  Wyoming  Washakie County, WY
# 1550582      2021 December  Wyoming              [Total]
# 1550583      2021 December  [Total]              [Total]
# 1550584       2021 [Total]  [Total]              [Total]
# 1550585  All Years [Total]  [Total]              [Total]
#
#                               Industry  \
# 0               Depository Institution
# 1               Depository Institution
# 2               Depository Institution
# 3               Depository Institution
# 4               Depository Institution
# ...                                ...
# 1550581  Money Services Business (MSB)
# 1550582  Money Services Business (MSB)
# 1550583  Money Services Business (MSB)
# 1550584  Money Services Business (MSB)
# 1550585  Money Services Business (MSB)
#
#                                   Suspicious Activity   Count
# 0                                               Check       3
# 1                              Counterfeit Instrument       2
# 2                                   Credit/Debit Card       1
# 3                                  Other Fraud (Type)       1
# 4        Provided Questionable or False Documentation       1
# ...                                               ...     ...
# 1550581                                       [Total]       2
# 1550582                                       [Total]     299
# 1550583                                       [Total]   14494
# 1550584                                       [Total]  151004
# 1550585                                       [Total]  288622
#
# [1550586 rows x 6 columns]

# %%
#delete the subtotal rows that contain "[Total]"
newdata1 = data[~data.isin(["[Total]"]).any(axis=1)]
newdata1
#newdata1.shape (1432673, 6)
# Out:
# (1432673, 6)

# %%
#splitting "Year Month" column, rejoining it back to df,  and then renaming the column
#this date format is for tableau efficiency
newdata1 =newdata1.join(newdata1["Year Month"].str.partition(" ")[[0,2]].rename({0:"Year",2:"Month"}, axis=1))
newdata1["Date"] = newdata1["Month"] +" "+ newdata1["Year"] 

#drop unnecessary columns
newdata1 = newdata1.drop(["Year Month", "Month"], axis=1)
newdata1
# Out:
#            State              Countym                       Industry  \
# 0        Alabama   Autauga County, AL         Depository Institution
# 1        Alabama   Autauga County, AL         Depository Institution
# 2        Alabama   Autauga County, AL         Depository Institution
# 3        Alabama   Autauga County, AL         Depository Institution
# 4        Alabama   Autauga County, AL         Depository Institution
# ...          ...                  ...                            ...
# 1550575  Wyoming     Uinta County, WY  Money Services Business (MSB)
# 1550576  Wyoming     Uinta County, WY  Money Services Business (MSB)
# 1550577  Wyoming     Uinta County, WY  Money Services Business (MSB)
# 1550579  Wyoming  Washakie County, WY  Money Services Business (MSB)
# 1550580  Wyoming  Washakie County, WY  Money Services Business (MSB)
#
#                                       Suspicious Activity  Count  Year  \
# 0                                                   Check      3  2020
# 1                                  Counterfeit Instrument      2  2020
# 2                                       Credit/Debit Card      1  2020
# 3                                      Other Fraud (Type)      1  2020
# 4            Provided Questionable or False Documentation      1  2020
# ...                                                   ...    ...   ...
# 1550575  Transaction(s) Below BSA Recordkeeping Threshold      1  2021
# 1550576          Two or More Individuals Working Together      7  2021
# 1550577                                              Wire      1  2021
# 1550579  Transaction(s) Below BSA Recordkeeping Threshold      1  2021
# 1550580          Two or More Individuals Working Together      1  2021
#
#                   Date
# 0         January 2020
# 1         January 2020
# 2         January 2020
# 3         January 2020
# 4         January 2020
# ...                ...
# 1550575  December 2021
# 1550576  December 2021
# 1550577  December 2021
# 1550579  December 2021
# 1550580  December 2021
#
# [1432673 rows x 7 columns]

# %%
#find rows that have missing values
null_data = newdata1[newdata1.isnull().any(axis=1)]
null_data.head() 
#no missing data in the SAR dataset as seen below
# Out:
# Empty DataFrame
# Columns: [State, Countym, Industry, Suspicious Activity, Count, Year, Date]
# Index: []

# %%
#rename column
newdata1.rename(columns={"Countym":"County"}, inplace=True) 

#changing this county name to match with the county name in the FIPS dataset
newdata1["County"].replace("Do̱a Ana County, NM","Dona Ana County, NM",inplace=True)
newdata1
# Out:
#            State               County                       Industry  \
# 0        Alabama   Autauga County, AL         Depository Institution
# 1        Alabama   Autauga County, AL         Depository Institution
# 2        Alabama   Autauga County, AL         Depository Institution
# 3        Alabama   Autauga County, AL         Depository Institution
# 4        Alabama   Autauga County, AL         Depository Institution
# ...          ...                  ...                            ...
# 1550575  Wyoming     Uinta County, WY  Money Services Business (MSB)
# 1550576  Wyoming     Uinta County, WY  Money Services Business (MSB)
# 1550577  Wyoming     Uinta County, WY  Money Services Business (MSB)
# 1550579  Wyoming  Washakie County, WY  Money Services Business (MSB)
# 1550580  Wyoming  Washakie County, WY  Money Services Business (MSB)
#
#                                       Suspicious Activity  Count  Year  \
# 0                                                   Check      3  2020
# 1                                  Counterfeit Instrument      2  2020
# 2                                       Credit/Debit Card      1  2020
# 3                                      Other Fraud (Type)      1  2020
# 4            Provided Questionable or False Documentation      1  2020
# ...                                                   ...    ...   ...
# 1550575  Transaction(s) Below BSA Recordkeeping Threshold      1  2021
# 1550576          Two or More Individuals Working Together      7  2021
# 1550577                                              Wire      1  2021
# 1550579  Transaction(s) Below BSA Recordkeeping Threshold      1  2021
# 1550580          Two or More Individuals Working Together      1  2021
#
#                   Date
# 0         January 2020
# 1         January 2020
# 2         January 2020
# 3         January 2020
# 4         January 2020
# ...                ...
# 1550575  December 2021
# 1550576  December 2021
# 1550577  December 2021
# 1550579  December 2021
# 1550580  December 2021
#
# [1432673 rows x 7 columns]

# %% [markdown]
# ##### SAR dataset (above) will be merged with the FIPS data set (below).
# The FIPS county code is a five-digit Federal Information Processing Standards (FIPS) code which uniquely identifies counties and county equivalents in the United States. The FIPS code is needed to accurately visualize county data in Tableau. When merging the datasets the first time, some of the issues I encountered where misspellings (capital case, hyphens and word spaces), outdated fips codes and even non-existant counties in the FinCen SAR stat database. All spelling corrections were made in the FIPS dataset to preserve the integrity of the FinCen dataset as much as possible.

# %%
# importing the FIPS dataset
fips = pd.read_excel(r"C:\Users\Ruben\Desktop\Python Repository\US_FIPS2.xlsx")

#make second row into the header
new_header = fips.iloc[0]
fips= fips[1:]
fips.columns = new_header
 
fips
#fips.dtypes
# Out:
# 0    FIPS State                 County FIPS County Name FIPS State Code  \
# 1       Alabama     Autauga County, AL          Autauga              01
# 2       Alabama     Baldwin County, AL          Baldwin              01
# 3       Alabama     Barbour County, AL          Barbour              01
# 4       Alabama        Bibb County, AL             Bibb              01
# 5       Alabama      Blount County, AL           Blount              01
# ...         ...                    ...              ...             ...
# 3123    Wyoming  Sweetwater County, WY       Sweetwater              56
# 3124    Wyoming       Teton County, WY            Teton              56
# 3125    Wyoming       Uinta County, WY            Uinta              56
# 3126    Wyoming    Washakie County, WY         Washakie              56
# 3127    Wyoming      Weston County, WY           Weston              56
#
# 0    FIPS County Code
# 1                 001
# 2                 003
# 3                 005
# 4                 007
# 5                 009
# ...               ...
# 3123              037
# 3124              039
# 3125              041
# 3126              043
# 3127              045
#
# [3127 rows x 5 columns]

# %%
#merge dataframes
mrgdata = pd.merge(fips,newdata1, how= "left", left_on=["County"], right_on=["County"]) 
mrgdata
# Out:
#         FIPS State              County FIPS County Name FIPS State Code  \
# 0          Alabama  Autauga County, AL          Autauga              01
# 1          Alabama  Autauga County, AL          Autauga              01
# 2          Alabama  Autauga County, AL          Autauga              01
# 3          Alabama  Autauga County, AL          Autauga              01
# 4          Alabama  Autauga County, AL          Autauga              01
# ...            ...                 ...              ...             ...
# 1432695    Wyoming   Weston County, WY           Weston              56
# 1432696    Wyoming   Weston County, WY           Weston              56
# 1432697    Wyoming   Weston County, WY           Weston              56
# 1432698    Wyoming   Weston County, WY           Weston              56
# 1432699    Wyoming   Weston County, WY           Weston              56
#
#         FIPS County Code    State                       Industry  \
# 0                    001  Alabama         Depository Institution
# 1                    001  Alabama         Depository Institution
# 2                    001  Alabama         Depository Institution
# 3                    001  Alabama         Depository Institution
# 4                    001  Alabama         Depository Institution
# ...                  ...      ...                            ...
# 1432695              045  Wyoming  Money Services Business (MSB)
# 1432696              045  Wyoming  Money Services Business (MSB)
# 1432697              045  Wyoming  Money Services Business (MSB)
# 1432698              045  Wyoming  Money Services Business (MSB)
# 1432699              045  Wyoming  Money Services Business (MSB)
#
#                                       Suspicious Activity  Count  Year  \
# 0                                                   Check    3.0  2020
# 1                                  Counterfeit Instrument    2.0  2020
# 2                                       Credit/Debit Card    1.0  2020
# 3                                      Other Fraud (Type)    1.0  2020
# 4            Provided Questionable or False Documentation    1.0  2020
# ...                                                   ...    ...   ...
# 1432695                                Other Fraud (Type)    1.0  2020
# 1432696  Suspicious use of multiple transaction locations    1.0  2021
# 1432697  Transaction(s) Below BSA Recordkeeping Threshold    1.0  2021
# 1432698  Suspicious use of multiple transaction locations    2.0  2021
# 1432699  Transaction(s) Below BSA Recordkeeping Threshold    3.0  2021
#
#                   Date
# 0         January 2020
# 1         January 2020
# 2         January 2020
# 3         January 2020
# 4         January 2020
# ...                ...
# 1432695  December 2020
# 1432696      June 2021
# 1432697      June 2021
# 1432698   October 2021
# 1432699   October 2021
#
# [1432700 rows x 11 columns]

# %%
#find rows that have missing values
null_data25 = mrgdata[mrgdata.isnull().any(axis=1)]
null_data25
#null_data25.to_csv("null_data25.csv") exported to excel for more research
#the large majority of the counties with missing data are sparsely populated counties that do not have SARs for the years 2021-2021
# Out:
#            FIPS State                    County   FIPS County Name  \
# 501032       Kentucky      Robertson County, KY          Robertson
# 725586        Montana         Carter County, MT             Carter
# 728371        Montana       Garfield County, MT           Garfield
# 728467        Montana  Golden Valley County, MT      Golden Valley
# 730073        Montana         McCone County, MT             McCone
# 731239        Montana      Petroleum County, MT          Petroleum
# 732928        Montana       Treasure County, MT           Treasure
# 734475       Nebraska         Arthur County, NE             Arthur
# 734476       Nebraska         Banner County, NE             Banner
# 734477       Nebraska         Blaine County, NE             Blaine
# 740736       Nebraska         Hooker County, NE             Hooker
# 741185       Nebraska      Keya Paha County, NE          Keya Paha
# 742971       Nebraska      McPherson County, NE          McPherson
# 926328   North Dakota          Slope County, ND              Slope
# 1116251  South Dakota        Buffalo County, SD            Buffalo
# 1117993  South Dakota         Hanson County, SD             Hanson
# 1118000  South Dakota         Hughes County, SD             Hughes
# 1172720         Texas         Borden County, TX             Borden
# 1203271         Texas      Glasscock County, TX          Glasscock
# 1211997         Texas        Hartley County, TX            Hartley
# 1225999         Texas         Kenedy County, TX             Kenedy
# 1226000         Texas           Kent County, TX               Kent
# 1230838         Texas         Loving County, TX             Loving
# 1258377         Texas        Terrell County, TX            Terrell
# 1351254      Virginia     Williamsburg city, VA  Williamsburg City
# 1409612     Wisconsin      Menominee County, WI          Menominee
# 1414094     Wisconsin          Pepin County, WI              Pepin
#
#         FIPS State Code FIPS County Code State Industry Suspicious Activity  \
# 501032               21              201   NaN      NaN                 NaN
# 725586               30              011   NaN      NaN                 NaN
# 728371               30              033   NaN      NaN                 NaN
# 728467               30              037   NaN      NaN                 NaN
# 730073               30              055   NaN      NaN                 NaN
# 731239               30              069   NaN      NaN                 NaN
# 732928               30              103   NaN      NaN                 NaN
# 734475               31              005   NaN      NaN                 NaN
# 734476               31              007   NaN      NaN                 NaN
# 734477               31              009   NaN      NaN                 NaN
# 740736               31              091   NaN      NaN                 NaN
# 741185               31              103   NaN      NaN                 NaN
# 742971               31              117   NaN      NaN                 NaN
# 926328               38              087   NaN      NaN                 NaN
# 1116251              46              017   NaN      NaN                 NaN
# 1117993              46              061   NaN      NaN                 NaN
# 1118000              46              065   NaN      NaN                 NaN
# 1172720              48              033   NaN      NaN                 NaN
# 1203271              48              173   NaN      NaN                 NaN
# 1211997              48              205   NaN      NaN                 NaN
# 1225999              48              261   NaN      NaN                 NaN
# 1226000              48              263   NaN      NaN                 NaN
# 1230838              48              301   NaN      NaN                 NaN
# 1258377              48              443   NaN      NaN                 NaN
# 1351254              51              830   NaN      NaN                 NaN
# 1409612              55              078   NaN      NaN                 NaN
# 1414094              55              091   NaN      NaN                 NaN
#
#          Count Year Date
# 501032       0  NaN  NaN
# 725586       0  NaN  NaN
# 728371       0  NaN  NaN
# 728467       0  NaN  NaN
# 730073       0  NaN  NaN
# 731239       0  NaN  NaN
# 732928       0  NaN  NaN
# 734475       0  NaN  NaN
# 734476       0  NaN  NaN
# 734477       0  NaN  NaN
# 740736       0  NaN  NaN
# 741185       0  NaN  NaN
# 742971       0  NaN  NaN
# 926328       0  NaN  NaN
# 1116251      0  NaN  NaN
# 1117993      0  NaN  NaN
# 1118000      0  NaN  NaN
# 1172720      0  NaN  NaN
# 1203271      0  NaN  NaN
# 1211997      0  NaN  NaN
# 1225999      0  NaN  NaN
# 1226000      0  NaN  NaN
# 1230838      0  NaN  NaN
# 1258377      0  NaN  NaN
# 1351254      0  NaN  NaN
# 1409612      0  NaN  NaN
# 1414094      0  NaN  NaN

# %%
# the "State" column cannot have missing values or else the tableau map will look like an incomplete puzzle with missing pieces
# to solve this, I populated the empty values in the "State" column with values from the "FIPS State" column 
# the "FIPS State" column is an addditional column that was kept in the merge and not necessarily needed
mrgdata["State"] = mrgdata["State"].fillna(mrgdata.pop("FIPS State"))
mrgdata
# Out:
#                      County FIPS County Name FIPS State Code FIPS County Code  \
# 0        Autauga County, AL          Autauga              01              001
# 1        Autauga County, AL          Autauga              01              001
# 2        Autauga County, AL          Autauga              01              001
# 3        Autauga County, AL          Autauga              01              001
# 4        Autauga County, AL          Autauga              01              001
# ...                     ...              ...             ...              ...
# 1432695   Weston County, WY           Weston              56              045
# 1432696   Weston County, WY           Weston              56              045
# 1432697   Weston County, WY           Weston              56              045
# 1432698   Weston County, WY           Weston              56              045
# 1432699   Weston County, WY           Weston              56              045
#
#            State                       Industry  \
# 0        Alabama         Depository Institution
# 1        Alabama         Depository Institution
# 2        Alabama         Depository Institution
# 3        Alabama         Depository Institution
# 4        Alabama         Depository Institution
# ...          ...                            ...
# 1432695  Wyoming  Money Services Business (MSB)
# 1432696  Wyoming  Money Services Business (MSB)
# 1432697  Wyoming  Money Services Business (MSB)
# 1432698  Wyoming  Money Services Business (MSB)
# 1432699  Wyoming  Money Services Business (MSB)
#
#                                       Suspicious Activity  Count  Year  \
# 0                                                   Check      3  2020
# 1                                  Counterfeit Instrument      2  2020
# 2                                       Credit/Debit Card      1  2020
# 3                                      Other Fraud (Type)      1  2020
# 4            Provided Questionable or False Documentation      1  2020
# ...                                                   ...    ...   ...
# 1432695                                Other Fraud (Type)      1  2020
# 1432696  Suspicious use of multiple transaction locations      1  2021
# 1432697  Transaction(s) Below BSA Recordkeeping Threshold      1  2021
# 1432698  Suspicious use of multiple transaction locations      2  2021
# 1432699  Transaction(s) Below BSA Recordkeeping Threshold      3  2021
#
#                   Date
# 0         January 2020
# 1         January 2020
# 2         January 2020
# 3         January 2020
# 4         January 2020
# ...                ...
# 1432695  December 2020
# 1432696      June 2021
# 1432697      June 2021
# 1432698   October 2021
# 1432699   October 2021
#
# [1432700 rows x 10 columns]

# %%
#verify that "State" column has zero missing values
null_data26 = mrgdata[mrgdata.isnull().any(axis=1)]
null_data26
# Out:
#                            County   FIPS County Name FIPS State Code  \
# 501032       Robertson County, KY          Robertson              21
# 725586          Carter County, MT             Carter              30
# 728371        Garfield County, MT           Garfield              30
# 728467   Golden Valley County, MT      Golden Valley              30
# 730073          McCone County, MT             McCone              30
# 731239       Petroleum County, MT          Petroleum              30
# 732928        Treasure County, MT           Treasure              30
# 734475          Arthur County, NE             Arthur              31
# 734476          Banner County, NE             Banner              31
# 734477          Blaine County, NE             Blaine              31
# 740736          Hooker County, NE             Hooker              31
# 741185       Keya Paha County, NE          Keya Paha              31
# 742971       McPherson County, NE          McPherson              31
# 926328           Slope County, ND              Slope              38
# 1116251        Buffalo County, SD            Buffalo              46
# 1117993         Hanson County, SD             Hanson              46
# 1118000         Hughes County, SD             Hughes              46
# 1172720         Borden County, TX             Borden              48
# 1203271      Glasscock County, TX          Glasscock              48
# 1211997        Hartley County, TX            Hartley              48
# 1225999         Kenedy County, TX             Kenedy              48
# 1226000           Kent County, TX               Kent              48
# 1230838         Loving County, TX             Loving              48
# 1258377        Terrell County, TX            Terrell              48
# 1351254     Williamsburg city, VA  Williamsburg City              51
# 1409612      Menominee County, WI          Menominee              55
# 1414094          Pepin County, WI              Pepin              55
#
#         FIPS County Code         State Industry Suspicious Activity  Count  \
# 501032               201      Kentucky      NaN                 NaN      0
# 725586               011       Montana      NaN                 NaN      0
# 728371               033       Montana      NaN                 NaN      0
# 728467               037       Montana      NaN                 NaN      0
# 730073               055       Montana      NaN                 NaN      0
# 731239               069       Montana      NaN                 NaN      0
# 732928               103       Montana      NaN                 NaN      0
# 734475               005      Nebraska      NaN                 NaN      0
# 734476               007      Nebraska      NaN                 NaN      0
# 734477               009      Nebraska      NaN                 NaN      0
# 740736               091      Nebraska      NaN                 NaN      0
# 741185               103      Nebraska      NaN                 NaN      0
# 742971               117      Nebraska      NaN                 NaN      0
# 926328               087  North Dakota      NaN                 NaN      0
# 1116251              017  South Dakota      NaN                 NaN      0
# 1117993              061  South Dakota      NaN                 NaN      0
# 1118000              065  South Dakota      NaN                 NaN      0
# 1172720              033         Texas      NaN                 NaN      0
# 1203271              173         Texas      NaN                 NaN      0
# 1211997              205         Texas      NaN                 NaN      0
# 1225999              261         Texas      NaN                 NaN      0
# 1226000              263         Texas      NaN                 NaN      0
# 1230838              301         Texas      NaN                 NaN      0
# 1258377              443         Texas      NaN                 NaN      0
# 1351254              830      Virginia      NaN                 NaN      0
# 1409612              078     Wisconsin      NaN                 NaN      0
# 1414094              091     Wisconsin      NaN                 NaN      0
#
#         Year Date
# 501032   NaN  NaN
# 725586   NaN  NaN
# 728371   NaN  NaN
# 728467   NaN  NaN
# 730073   NaN  NaN
# 731239   NaN  NaN
# 732928   NaN  NaN
# 734475   NaN  NaN
# 734476   NaN  NaN
# 734477   NaN  NaN
# 740736   NaN  NaN
# 741185   NaN  NaN
# 742971   NaN  NaN
# 926328   NaN  NaN
# 1116251  NaN  NaN
# 1117993  NaN  NaN
# 1118000  NaN  NaN
# 1172720  NaN  NaN
# 1203271  NaN  NaN
# 1211997  NaN  NaN
# 1225999  NaN  NaN
# 1226000  NaN  NaN
# 1230838  NaN  NaN
# 1258377  NaN  NaN
# 1351254  NaN  NaN
# 1409612  NaN  NaN
# 1414094  NaN  NaN

# %%
#fill missing values with 0
mrgdata[["Count"]] = mrgdata[["Count"]].fillna(0)

#change data type back to integer
mrgdata["Count"] = mrgdata["Count"].astype(int)

#mrgdata.dtypes
#output as csv to be imported into tableau
mrgdata.to_csv("50states.20-21.countysuspv2.csv")
